# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import cmath

# %%
xO = []
x = []
yO = []
y = []

for i in range(100000):
    R = 100000
    xO.append(-i)
    x.append(i)
    yO.append(cmath.sqrt(R ** 2 - i ** 2))
    y.append(-cmath.sqrt(R ** 2 - i ** 2))

plt.figure(figsize = (5, 5))
plt.title('График окружности')
plt.plot(xO, yO, color='r')
plt.plot(x, y, color='r')
plt.plot(xO, y, color='r')
plt.plot(x, yO, color='r')
plt.show()

# %%
xO = []
x = []
yO = []
y = []

for i in range(40000):
    a = 40000
    b = 20000   
    xO.append(-i)
    x.append(i)
    yO.append(cmath.sqrt(b ** 2 - b ** 2 * (i ** 2 / a ** 2)))
    y.append(-cmath.sqrt(b ** 2 - b ** 2 * (i ** 2 / a ** 2)))
    
plt.title('График эллипса')
plt.plot(xO, yO, color='b')
plt.plot(x, y, color='b')
plt.plot(xO, y, color='b')
plt.plot(x, yO, color='b')
plt.show()

# %%
xO = []
x = []
yO = []
y = []

for i in range(1000):
    a = 400
    b = 200
    yO.append(-i)
    y.append(i)
    xO.append(cmath.sqrt(a ** 2 + a ** 2 * (i ** 2 / b ** 2)))
    x.append(-cmath.sqrt(a ** 2 + a ** 2 * (i ** 2 / b ** 2)))
  
plt.title('График гиперболы')
plt.plot(xO, yO, color='g')
plt.plot(x, y, color='g')
plt.plot(xO, y, color='g')
plt.plot(x, yO, color='g')
plt.show()
